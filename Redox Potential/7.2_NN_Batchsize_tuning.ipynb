# %% [markdown]
# In this notebook, we will
# - Make a feed forward neural network (NN) model with 59 Rdkit descriptors
# - Use Learning rate = 0.01 (from 7.1_NN_LearningRate_tuning)
# - find the optimial batch size for NN training
# - Predict the ERed of molecules in the test dataset
# - save the model with pickle package

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# import custom functions from the python file
import sys
sys.path.append('../') # path of the directory that contains Chemfunctions.py
import Chemfunctions as chemfun


# Plots
import matplotlib.pyplot as plt
import seaborn as sns

# RDKit 
import rdkit.Chem as Chem

# %% [markdown]
# Need val data for training NN so read the unscaled train features

# %%
X_train = pd.read_csv(r'./Data/X_train_70pc_unscaled.csv')
X_test = pd.read_csv(r'./Data/X_test_30pc_unscaled.csv')
y_train = pd.read_csv(r'./Data/y_train_70pc_target.csv')
y_test = pd.read_csv(r'./Data/y_test_30pc_target.csv')

print(f'X_train.shape={X_train.shape}, y_train.shape={y_train.shape}')
print(f'X_test.shape={X_test.shape}, y_test.shape={y_test.shape}')
# Out:
# X_train.shape=(3809, 59), y_train.shape=(3809, 1)
# X_test.shape=(1633, 59), y_test.shape=(1633, 1)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5), sharex=True)
sns.histplot(ax=axs[0],x=y_train["ERed"], bins=30, kde=True,color="tab:blue")
sns.histplot(ax=axs[1],x=y_test["ERed"], bins=30, kde=True,color="tab:orange")
axs[0].set_xlabel("ERed")
axs[1].set_xlabel("ERed")
axs[0].set_ylabel("Count")
axs[1].set_ylabel("Count")
axs[0].set_title("Train")
axs[1].set_title("Test")
plt.show()

# %% [markdown]
# # NN model

# %%
import tensorflow as tf

# %% [markdown]
# let's make a neural network (NN) with an input layer of size of X_train.shape[1], with tf we need to pass input_shape as iterable object so [X_train.shape[1]] will run w/o error
#
# NN will have
# - 1st hidden layer with 64 units and relu activation
# - 2nd hidden layer with 32 units and relu activation
# - 3rd hidden layer with 16 units and sigmoid activation
# - output layer with 1 unit

# %%
# tf.keras.backend.clear_session()
input_shape=[X_train.shape[1]]
model = tf.keras.Sequential([

	tf.keras.layers.Dense(units=64, activation='relu',
						input_shape=input_shape),
	tf.keras.layers.Dense(units=32, activation='relu'),
	tf.keras.layers.Dense(units=16, activation='sigmoid'),
	# tf.keras.layers.Dense(units=1,activation='linear')
	tf.keras.layers.Dense(units=1)
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                3840
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 6,465
# Trainable params: 6,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
# adam optimizer works pretty well for
# all kinds of problems and is a good starting point
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),loss='mean_squared_error')

# %% [markdown]
# Make a val set and scale test data set too

# %%
from sklearn.model_selection import train_test_split

train_x, val_x, train_y, val_y = train_test_split(X_train,y_train,test_size=0.1, random_state=32)
print(f'train_x.shape = {train_x.shape}, val_x.shape = {val_x.shape}, train_y.shape = {train_y.shape}, val_y.shape = {val_y.shape}')
# Out:
# train_x.shape = (3428, 59), val_x.shape = (381, 59), train_y.shape = (3428, 1), val_y.shape = (381, 1)

# %% [markdown]
# scaling

# %%
temp=train_x.copy()
train_x,val_x=chemfun.do_scaling(xtrain=train_x,xtest=val_x)
_,test_x=chemfun.do_scaling(xtrain=temp,xtest=X_test)
# Out:
# returning scaled train and test data
# returning scaled train and test data

# %%
losses = model.fit(train_x, train_y,

				validation_data=(val_x,val_y),
					
				# it will use 'batch_size' number
				# of examples per example
				batch_size=128,
				epochs=30, # total epoch

				)
# tf.keras.backend.clear_session()
# Out:
# Epoch 1/30
# 27/27 [==============================] - 1s 6ms/step - loss: 0.1003 - val_loss: 0.0112
# Epoch 2/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0117 - val_loss: 0.0073
# Epoch 3/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0062
# Epoch 4/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0055
# Epoch 5/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 6/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0053
# Epoch 7/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 8/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 9/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 10/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0057
# Epoch 11/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 12/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 13/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0053
# Epoch 14/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0053
# Epoch 15/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0053
# Epoch 16/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0054
# Epoch 17/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0053
# Epoch 18/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0054
# Epoch 19/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0055
# Epoch 20/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 21/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0053
# Epoch 22/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0055
# Epoch 23/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0054
# Epoch 24/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0054
# Epoch 25/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0063
# Epoch 26/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0058
# Epoch 27/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0057
# Epoch 28/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0057
# Epoch 29/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0057
# Epoch 30/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0058

# %%
loss_df = pd.DataFrame(losses.history)

# history stores the loss/val
# loss in each epoch

# loss_df is a dataframe which
# contains the losses so we can
# plot it to visualize our model training
loss_df.loc[:,['loss','val_loss']].plot()
# Out:
# <AxesSubplot: >

# %%
def pairity_plot2(model,X_train,X_test,y_train,y_test):
    import matplotlib.pyplot as plt
    """
    This function will fit the model and make parity plot with residuals
    """
    # model.fit(X_train,y_train)
    # print(y_test.shape,y_train.shape)
    
    ytest_pred=model.predict(X_test)

    ytrain_pred=model.predict(X_train)
    
    ytrain_pred=np.array(ytrain_pred).reshape(-1,1)
    ytest_pred=np.array(ytest_pred).reshape(-1,1)
    y_test=np.array(y_test).reshape(-1,1)
    y_train=np.array(y_train).reshape(-1,1)

    fig, axs = plt.subplots(1,2,figsize=(10,5),sharex=True)
    
    fig.suptitle(f"model={model}")

    from sklearn.metrics import mean_squared_error as mse
    from sklearn.metrics import r2_score as r2

    axs[0].plot([y_train.min()-0.05,y_train.max()+0.05],[y_train.min()-0.05,y_train.max()+0.05],':k',linewidth=2)
    axs[0].set_xlim([y_train.min()-0.05,y_train.max()+0.05])
    axs[0].set_ylim([y_train.min()-0.05,y_train.max()+0.05])
    axs[0].set_xlabel('Predicted (V)')
    axs[0].set_ylabel('DFT Calculated (V)')

    errors_=f"Train: R2 = {r2(y_true=y_train,y_pred=ytrain_pred):0.2f},RMSE = {np.sqrt(mse(y_true=y_train,y_pred=ytrain_pred)):0.2f}"
    axs[0].scatter(ytrain_pred,y_train,label=errors_)
    
    errors_=f"Test: R2 = {r2(y_true=y_test,y_pred=ytest_pred):0.2f},RMSE = {np.sqrt(mse(y_true=y_test,y_pred=ytest_pred)):0.2f}"
    axs[0].scatter(ytest_pred,y_test,label=errors_)

    axs[0].legend()

    axs[1].scatter(ytest_pred,(y_test-ytest_pred))
    axs[1].plot([y_train.min()-0.05,y_train.max()+0.05],[0,0],':k',linewidth=2)
    axs[1].set_xlabel('Predicted (V)')
    # axs[0].set_xlabel('Predicted (V)')
    axs[1].set_ylabel('Residual = Actual - Predicted (V)')
    plt.show()

# %%
pairity_plot2(model=model,X_train=train_x,X_test=val_x,y_train=train_y["ERed"],y_test=val_y["ERed"])
# Out:
# 12/12 [==============================] - 0s 665us/step
# 108/108 [==============================] - 0s 520us/step

# %%
pairity_plot2(model=model,X_train=train_x,X_test=test_x,y_train=train_y["ERed"],y_test=y_test["ERed"])
# Out:
# 52/52 [==============================] - 0s 551us/step
# 108/108 [==============================] - 0s 478us/step

# %%
# ## save model
# save_path = r'./Models/NN_Regression_with_optimal_lr.h5'
# model.save(save_path)
# ## load tensorflow model
# # model = tf.keras.models.load_model(save_path)

# %% [markdown]
# - Check the effect of learning rate on the training, and validation losses
# - Compare the errors on test data with base model

# %%
# learning_rates=10**np.linspace(-4,1,5)
batch_size = [32, 64, 128, 256,512,1024]
print(batch_size)
# Out:
# [32, 64, 128, 256, 512, 1024]

# %%
import time
def helper_bs(bs):
    # del model
    # model = tf.keras.Sequential()
    # tf.keras.backend.clear_session()

    start=time.time()
    model = tf.keras.Sequential([

        tf.keras.layers.Dense(units=64, activation='relu',
                            input_shape=[X_train.shape[1]]),
        tf.keras.layers.Dense(units=32, activation='relu'),
        tf.keras.layers.Dense(units=16, activation='sigmoid'),
        # tf.keras.layers.Dense(units=1,activation='linear')
        tf.keras.layers.Dense(units=1)
    ])
    # model.summary()

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),loss='mean_squared_error')

    losses = model.fit(train_x, train_y,

				validation_data=(val_x,val_y),
					
				# it will use 'batch_size' number
				# of examples per example
				batch_size=bs,
				epochs=50, # total epoch
                verbose=0 

				)
    end=time.time()
    loss_df = losses.history

    # tf.keras.backend.clear_session()
    return loss_df,end-start

# %%
losses_bs={}
time_={}
temp=0
for bs in batch_size:
    tf.keras.backend.clear_session()
    losses_bs[f"bs_{temp}"],time_[f"bs_{temp}"]=helper_bs(bs=bs)
    temp+=1
    # del model

# %%
# fig
temp=0
for key, losd in losses_bs.items():
    # losd.loc[:,['loss','val_loss']].plot()\

    plt.plot(np.arange(len(losd["loss"])),losd["loss"],label=f"{key} = {batch_size[temp]}")
    temp+=1
plt.ylim(0,0.05)
plt.xlabel("Epochs")
plt.title("Train")
plt.ylabel("MSE")
plt.legend()
plt.show()

# %%
# fig
temp=0
for key, losd in losses_bs.items():
    # losd.loc[:,['loss','val_loss']].plot()\

    plt.plot(np.arange(len(losd["val_loss"])),losd["val_loss"],label=f"{key} = {batch_size[temp]}")
    temp+=1
plt.ylim(0,0.05)
plt.xlabel("Epochs")
plt.title("Validation")
plt.ylabel("MSE")
plt.legend()
plt.show()

# %%
keys=list(losses_bs.keys())
nr_rows = 4
nr_cols = 3
sns.set(style='white')
fig, axs = plt.subplots(nr_rows, nr_cols, figsize=(nr_cols*3.5,nr_rows*3),sharex=False)

for r in range(0,nr_rows):
    
    for c in range(0,nr_cols):  
        i = r*nr_cols+c
        
        if i < len(losses_bs):

            # axs[r][c].set_title(f"{keys[i]} = {learning_rates[i]}, {min(y):0.2f}")
            y=losses_bs[keys[i]]["loss"]
            axs[r][c].axhline(0.01,c="black",ls=":")
            axs[r][c].set_title(f"{keys[i]} = {batch_size[i]}")
            axs[r][c].plot(np.arange(len(y)),y,label=f"train, {y[-1]*1000:0.2f}")
            y=losses_bs[keys[i]]["val_loss"]
            axs[r][c].plot(np.arange(len(y)),y,label=f"val, {y[-1]*1000:0.2f}")
            axs[r][c].legend()
            axs[r][c].set_xlabel("Epochs")
            axs[r][c].set_ylabel("MSE")
            axs[r][c].set_ylim(0,0.05)
            # axs[r][c].text(f"{y.min():0.2f}")

        else:
            fig.delaxes(axs[r][c])
            
plt.tight_layout()    
plt.show()

# %% [markdown]
# - With the learning rate = 0.01, we can achieve both the speed and accuracy

# %% [markdown]
# # We will train out NN with the Batch size 128 (less overfitting)

# %% [markdown]
# - with smaller batch size, less memory is needed, however we need to train (update model parameters) multiple times (more steps in a 1 epoch), as a result training time increases but the model become more robust (less overfitting, smaller validation error)
# - with large batch size, more memory is needed, however we train model less often (becasue of less steps in a 1 epoch), as a result training is fast but model might not be robust or may overfit (higher validation error)

# %% [markdown]
# ## Training time vs batchsize

# %%
plt.ylabel("Training time (s)")
plt.xlabel("Batch size")
plt.plot(np.arange(len(time_.keys())),time_.values(),'-o')
plt.xticks(np.arange(len(time_.keys())),[str(x) for x in batch_size])
plt.show()

# %% [markdown]
# # Epochs required to reach certain accuracy

# %%
x=batch_size
y=[np.where(np.array(losses_bs[key]["val_loss"])<0.006)[0][0] for key in losses_bs.keys()]
plt.plot(x,y,'-o')
plt.ylabel("Epoch at which MSE < 0.006")
plt.xlabel("Batch_size")
# plt.ylabel("Mini. Epoch")
plt.xticks(x,[str(s) for s in x ])
plt.show()
